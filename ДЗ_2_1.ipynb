# %%
import pandas as pd
import numpy as np

# %%
import nltk
from nltk.corpus import stopwords

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.metrics import classification_report
from transformers import BertTokenizer, BertModel
import torch

# %%
tweet_train = pd.read_csv('train.csv')
tweet_test = pd.read_csv('test.csv')

# %%
tweet_train.shape
# Out:
# (31962, 3)

# %%
tweet_test.shape
# Out:
# (17197, 2)

# %% [markdown]
# подсчет слов

# %%
tweet_train['word_count'] = tweet_train['tweet'].apply(lambda x: len(str(x).split(' ')))

# %%
tweet_test['word_count'] = tweet_test['tweet'].apply(lambda x: len(str(x).split(' ')))

# %%
tweet_train.head()
# Out:
#    id  label                                              tweet  word_count
# 0   1      0   @user when a father is dysfunctional and is s...          21
# 1   2      0  @user @user thanks for #lyft credit i can't us...          22
# 2   3      0                                bihday your majesty           5
# 3   4      0  #model   i love u take with u all the time in ...          17
# 4   5      0             factsguide: society now    #motivation           8

# %%
tweet_test.head()
# Out:
#       id                                              tweet  word_count
# 0  31963  #studiolife #aislife #requires #passion #dedic...          12
# 1  31964   @user #white #supremacists want everyone to s...          20
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...          15
# 3  31966  is the hp and the cursed child book up for res...          24
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...          18

# %% [markdown]
# число символов в строке

# %%
tweet_train['char_count'] = tweet_train['tweet'].str.len() #с пробелами
tweet_test['char_count'] = tweet_test['tweet'].str.len()

# %% [markdown]
# нужно избавиться от мелких слов из-за высокой значимости в них - stop слов с помощью nltk

# %%
nltk.download('stopwords')
set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stop = stopwords.words('english')

# %%
tweet_train['stopwords'] = tweet_train['tweet'].apply(lambda x: len([x for x in x.split() if x in stop]))
tweet_test['stopwords'] = tweet_test['tweet'].apply(lambda x: len([x for x in x.split() if x in stop]))

# %% [markdown]
# удаление стоп слов

# %%
tweet_train['tweet'] = tweet_train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
tweet_test['tweet'] = tweet_test['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# удаление цифр

# %%
tweet_train['tweet'] = tweet_train['tweet'].str.replace('\d+','', regex=True)
tweet_test['tweet'] = tweet_test['tweet'].str.replace('\d+','', regex=True)

# %% [markdown]
# надо удалить пунктуацию и лишние символы

# %%
tweet_train['tweet'] = tweet_train['tweet'].str.replace('\d+','', regex=True)
tweet_test['tweet'] = tweet_test['tweet'].str.replace('\d+','', regex=True)

# %%
tweet_train['tweet'] = tweet_train['tweet'].str.replace('[^\w\s]','', regex=True)
tweet_test['tweet'] = tweet_test['tweet'].str.replace('[^\w\s]','', regex=True)

# %%
tf1 = (tweet_train['tweet'][1:2]).apply(lambda x: pd.value_counts(x.split(' '))).sum(axis=0).reset_index()
tf1.columns = ['words', 'tf']
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_11104\2651025578.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tf1 = (tweet_train['tweet'][1:2]).apply(lambda x: pd.value_counts(x.split(' '))).sum(axis=0).reset_index()
# C:\Users\A\AppData\Local\Temp\ipykernel_11104\2651025578.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   tf1 = (tweet_train['tweet'][1:2]).apply(lambda x: pd.value_counts(x.split(' '))).sum(axis=0).reset_index()

# %%
for i, word in enumerate(tf1['words']):
    tf1.loc[i, 'idf'] = np.log(tweet_train.shape[0]/(len(tweet_train[tweet_train['tweet'].str.contains(word)])))

# %%
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1
# Out:
#           words  tf        idf      tfidf
# 0          user   2   1.054454   2.108909
# 1        thanks   1   4.597751   4.597751
# 2          lyft   1   8.762865   8.762865
# 3        credit   1   7.327781   7.327781
# 4          cant   1   3.538194   3.538194
# 5           use   1   1.005985   1.005985
# 6         cause   1   5.610129   5.610129
# 7         offer   1   6.522155   6.522155
# 8    wheelchair   1   9.273691   9.273691
# 9          vans   1   8.426393   8.426393
# 10          pdx   1   8.762865   8.762865
# 11  disapointed   1  10.372303  10.372303
# 12   getthanked   1   9.679156   9.679156

# %% [markdown]
# делю тренировочные данные на трейн и тест

# %%
X_full = tweet_train['tweet']
y_full = tweet_train['label']

# %%
X_train_text, X_val_text, y_train, y_val = train_test_split(
    X_full, y_full, test_size=0.2, random_state=42
)

# %% [markdown]
# TF-IDF

# %%
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word', stop_words = 'english', ngram_range=(1,3))
X_train_tfidf = tfidf.fit_transform(X_train_text)
X_val_tfidf = tfidf.transform(X_val_text)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________
# Мультиномиальный Байес тк после TruncatedSVD генерятся отрицательные значения, поэтому делаю его до SVD

# %%
nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)
y_pred = nb.predict(X_val_tfidf)

# %%
print(classification_report(y_val, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      5937
#            1       0.87      0.25      0.39       456
#
#     accuracy                           0.94      6393
#    macro avg       0.91      0.62      0.68      6393
# weighted avg       0.94      0.94      0.93      6393

# %% [markdown]
# _______________________________________________________________________________________________________________________________________________________

# %%
svd = TruncatedSVD(n_components=100, random_state=42)
X_svd_train = svd.fit_transform(X_train_tfidf)
X_svd_val = svd.transform(X_val_tfidf)

# %%
models = {'Logistic_Regression':LogisticRegression(),
          'Random_Forest':RandomForestClassifier(),
          'Naive_Bayes':GaussianNB()}

# %%
for name, model in models.items():

    model.fit(X_svd_train, y_train)
    y_pred = model.predict(X_svd_val)

    print(f'\n--- TF-IDF + TruncatedSVD + {name} ---')
    print(classification_report(y_val, y_pred, zero_division=1))
# Out:
# --- TF-IDF + TruncatedSVD + Logistic_Regression ---
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5937
#            1       0.81      0.18      0.30       456
#
#     accuracy                           0.94      6393
#    macro avg       0.87      0.59      0.63      6393
# weighted avg       0.93      0.94      0.92      6393
#
#
# --- TF-IDF + TruncatedSVD + Random_Forest ---
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5937
#            1       0.75      0.30      0.43       456
#
#     accuracy                           0.94      6393
#    macro avg       0.85      0.65      0.70      6393
# weighted avg       0.93      0.94      0.93      6393
#
#
# --- TF-IDF + TruncatedSVD + Naive_Bayes ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.59      0.74      5937
#            1       0.14      0.87      0.24       456
#
#     accuracy                           0.61      6393
#    macro avg       0.56      0.73      0.49      6393
# weighted avg       0.92      0.61      0.70      6393

# %% [markdown]
# Далее я пробовал реализовать эмбендинг взвешенных по attention используя сначала сберовскую нейросеть, после нашел как использовать Bert

# %% [markdown]
# эмбендинг взвешенных по attention

# %%
sentences = tweet_train['tweet'].tolist()

# %%
sentences
# Out:
# ['user father dysfunctional selfish drags kids dysfunction run',
#  'user user thanks lyft credit cant use cause offer wheelchair vans pdx disapointed getthanked',
#  'bihday majesty',
#  'model love u take u time urð ðððð ððð',
#  'factsguide society motivation',
#  ' huge fan fare big talking leave chaos pay disputes get there allshowandnogo',
#  'user camping tomorrow user user user user user user user dannyâ',
#  'next school year year examsð cant think ð school exams hate imagine actorslife revolutionschool girl',
#  'won love land allin cavs champions cleveland clevelandcavaliers â',
#  'user user welcome  gr ',
#  'â ireland consumer price index mom climbed previous   may blog silver gold forex',
#  'selfish orlando standwithorlando pulseshooting orlandoshooting biggerproblems selfish heabreaking values love ',
#  'get see daddy today days gettingfed',
#  'user cnn calls michigan middle school build wall chant  tcot',
#  'comment australia opkillingbay seashepherd helpcovedolphins thecove helpcovedolphins',
#  'ouchjunior angryðgot junior yugyoem omg',
#  'thankful paner thankful positive',
#  'retweet agree',
#  'friday ð smiles around via ig user user cookies make people',
#  'know essential oils made chemicals',
#  'euro people blaming ha conceded goal fat rooney gave away free kick knowing bale hit there',
#  'sad little dude badday coneofshame cats pissed funny laughs',
#  'product day happy man wine tool whos weekend time open amp drink up',
#  'user user lumpy says  prove lumpy',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'beautiful sign vendor   upsideofflorida shopalyssas love',
#  'user smiles media  ðð pressconference antalya turkey  sunday throwback love ððâï',
#  'great panel mediatization public service ica',
#  'happy fathers day user ðððð',
#  ' people went nightclub good night  mans actions means people lost families forever riporlando',
#  'never chance vote presidential candidate excited cycle looks different',
#  'alohafriday time not exist positivevibes hawaiian user user user user',
#  'user rip fellow nohern ireland fan sadley passed away tonight gawa forever singing cheering fire',
#  'hard monday due cloudy weather disabling oxygen production today goodnight badmonday',
#  'unbelievable st century need something like this again neverump xenophobia',
#  'taylorswift bull up dominate bull direct whatever want do w',
#  'morning travelingram dalat ripinkylife',
#  'user one word tells all photoshop enoughisenough dontphotoshopeverything wheresallthenaturalphotos',
#  'oh cedarpoint waited  hours valravn line stopped working close',
#  'thankful sunshine thankful positive',
#  'finally finish book working awhile bookworm ontothenextnovel',
#  'yup knicks fan hard easier nba fan playoffs roll around ð',
#  'life social networking embrace day',
#  'mom shares bihday user bihday snake see weekend ðð¼',
#  'lovely echeveria bloomsflowers grow gardening iphonesia bliss blooms basilicabotanica',
#  'amazing i_am positive affirmation',
#  'model love u take u time urð ðððð ððð',
#  'whenever im something goes wrong ',
#  'feeling blue illustration',
#  'best pa life knowing are ðâïð¼ð â',
#  'abc getting ready  remove victums frm pulseclub prayfororlando',
#  'bihday got nose job user ððððð bihday petunia love ð',
#  'concelebrate albanpilgrimage first time user',
#  'user let scumbaggery begin',
#  'thank you ðð super love it âï zpamdelacruz wedding  dolores capas tarlac',
#  'scourge playing baroque pieces piano beyond belief',
#  'user lets fight love peace',
#  'happy fatherâs day mr rayos video fathers day rayos world hotvideo videos',
#  'user ascot times babe âïâï ascot fashion monochrome style instahappyday',
#  'weekendis hereððððð selfie yolo xoxo likelike',
#  'happy work conference right mindset leads cultureofdevelopment organizations work mindset',
#  'christina grimmies last performance shot via user christinarip voice christinagrimmie',
#  'ready dance roar preschoolers students proudâ',
#  'really hu feelings ',
#  'user wife adore miss poland show surgery name bridget amp everything',
#  'user jealous right now chatiado',
#  'celebrate every man played fatherly role fathers day',
#  'sure happy ðð½ðð½ðð½ hour',
#  'ðthe white establishment cant blk folx running around loving promoting greatness',
#  'good morning journey begins ðððð³ travel yeah thejourneybegins helloâ',
#  'user  luv hottweets like â âvenusexchangeâ',
#  'new brochures arrived exciting aworks solutions',
#  'much stuff happening florida first orlando shooting disneygatorattack two year old kidðð',
#  'user ferrari itðªð¼ sake championship gp clearly turning point rb ferrarimercsð',
#  'aced first test proud',
#  'seeks probe udtapunjab leak points finger amarinder aap',
#  'user wrapping senseaboutmaths user th user user user',
#  'user hey white people call people white user race identity medâ',
#  'user user might be shown today regurgitated talking points name calling',
#  'sometimes raise brows raise bar golfstrengthandconditioning strong felixfoisgolf',
#  'ððð greathonour careerconvos user user',
#  'user designing innovative learning space user include wateringhole cave mountaintop campfire user hâ',
#  'altright uses amp insecurity lure men whitesupremacy',
#  'carrying gun helped cant take you gun control stop black market terrorism get worse',
#  'use power mind heal body  altwaystoheal healthy peace',
#  'woohoo  weeks go',
#  'far away place family members hus',
#  'ready rehearse tonight new music new videos look announcement midweek newmusic watchthisspace guitar',
#  'monday nights pm up channel finally get see fuss about',
#  'watching new episodes user user',
#  'user offline nice long night ð snapchat user redhead vermillionred',
#  ' things incredibly people',
#  'yes received acceptance letter masters back user october goodtimes history',
#  'daughter riding bike around driveway son playing guitar us enjoy ðº campfire summeime memories',
#  'omg loving station way jam work getting work done course memories user',
#  'user always hope one day get hug you think gonna happen anytime soon',
#  'model love u take u time urð ðððð ððð',
#  'couple sex fat naked japanese girls',
#  'hump hump day humpersð  edwardsville pennsylvania',
#  'personalised we gbp  get here shop cool home fun',
#  'truly sick ppl there',
#  'trump calling obama resign orlando shootings boy point  years talk change',
#  'user user user user long now nashvilletour nashvilleforever ððð',
#  'â eurusd clears  barrier jumps fresh week high blog silver gold forex',
#  'going la tomorrow',
#  'thankful good friends thankful positive',
#  'still wrap head around fact christinagrimmie gone fact man destroyed prayfororlando',
#  'received dis user cant wait sta baking eyelids ðððððð ðððâ',
#  'playing vigilfororlando harp clonakilty rip via user',
#  'user yes yes yes ihavenofriends someonecomewithme',
#  'sundayð weekend relax icon woman sundaymorning sunday marilynmonroe',
#  'user interested linguistics address race amp  racism power raciolinguistics bringsâ',
#  'one beloved long lost cds recovered thanks apple music ',
#  'marvel song musica weed ripchristina adele dance vine user',
#  'user user mocked obama black user user user user brexit',
#  'â under spell brexit referendum  commerzbank blog silver gold forex',
#  ' amazing health benefits cucumbers healthy  altwaystoheal',
#  'model love u take u time urð ðððð ððð',
#  'work ðªððð¼ ofw pinoy followme igers instagood smile love ',
#  'toradora anime animeedit made it breakups alone lonely',
#  ' laps pool k ride done picked gym membership form',
#  'cotd polar bear climb racing angry polar bear climb racing polar bear living cold places looking',
#  'user user gets angry muslim assassinating  much',
#  'happy snappy ðð¼ waiting football football snapchat',
#  'friday miss you fringesqcbagssummer ððððððó¾ð',
#  'nochebuena lasvegas usa  las vegas strip',
#  'fleurette ðð instaboyinstamansefieseptumfriend smilesblackandwhite',
#  'sad branches itâs rainy day writing tears flying birds haiku lines micropoetry',
#  'yeah new buttons mail ð pretty  jewelrymaking buttons',
#  'user driver hit female moose river rd weston moose killed driver ok crews removing animal',
#  'afterpas made japan ï¼madeinjapan eos ï¼cute fun cawaii love strawberry tomato',
#  'people protesting trump republican wonthey trump fuhered ampâ',
#  'need find way spend time always mind   me boy guy â',
#  ' update  social analytics photooftheday igers likes',
#  'anyone know date doj fbi became corrupted emailgate hillary shameful disgraceful ridiculous',
#  'stupidity makes even negligencewhy put sachintendulkar installation u going take off',
#  'ððððââï ãããã bihdayð thbihday ð bestfriend ð loveð¼',
#  'user ð impoant thing enjoy life   itâs matters life sho poohu',
#  'happy bihday chris evansððððððð great actor human ððð³ðððððð chrisevans bihdayâ',
#  'heas thoughts prayers go  people murdered  gay nightclub florida',
#  'user demoing guitars new album newalbum indie guitars echobelly',
#  'retweeted lion pro user tgif webmareting seo community management weekend',
#  'â nzdusd targets  week sma  blog silver gold forex',
#  'user pretty bad bihday weeks before far worst ever ð bihdayweeksucks bithday tâ',
#  'blessed worked sas best leading ladiesðð',
#  'happiest place eah ð disneysmagickingdom disney magickingdom disneyland orlandoâ',
#  'kinda among humans again',
#  'found user user exclaiming user gr blains hair nite ð',
#  'user lt listen beautiful best friend user singing amazing voice lt lt lt lt ',
#  'n healthy freedom effo present merely means effo stored past â theodore rooseveltâ',
#  'know yall  aint going know  love commitment trust faithful',
#  'yes call michelleobama gorilla racists long thought black people betâ',
#  'newarkfestival us year waiting show sta rd year running',
#  'internet broken cant watch netflix mochithepug puglife',
#  'user user user thatthen whatbusiness usual',
#  'hbd dick suckin tequila lovin slut wouldnt want u way ðð justalillate butstillontime',
#  'smaller hands show barry probably lied knicks game sucked golfâ',
#  'good morning friday everyone weekend goodmorning friday girls love florida',
#  'challenges aaps claim  punjabis drugaddicts dares prove',
#  'tracerequest sending deepest condolences orlando gay families zimbabwe gay community hea touched',
#  'new selfie ÂÂ guy mato chapones',
#  'saturday afternoon chi meet friends user user user',
#  'model love u take u time urð ðððð ððð',
#  'soed nut amp bolts bloke',
#  'aww yeah good bing bong bing bong',
#  'dawned  months seeing user live excited ððð vfest summer',
#  'user happy th bihday shane robe watson bihday shane watson australia cricker',
#  'user user point one finger user millions pointed right back you jewishsupremacist',
#  'sad hear announcers say it may moved player one two lead whoknows',
#  'radio going coldplay tonight oh yes',
#  'u think like too god coming me god keeping ',
#  'user terrorist  constitutional rights another excuse republicans appease nra gun control measures ',
#  'user user gloucesterrugby',
#  'user sad user happened',
#  'everyone everything sad together alone up down fine dandy lonely exuberant depressed halffull halfempty',
#  'mikeashley sposdirectshame  perhapse good example need protect workersrights within europe euref remain',
#  'angry birds stella bad princess birds stella bad princess birdsstellabadprincess time post wedâ',
#  'check user incredibly made great memories great people  ',
#  'saw shi last night said rip cared really',
#  'user hilarious user already blocked user asking one paicularly difficult question user',
#  'devastating news hea goes victims families orlando heabreaking',
#  'happiness state arrive at manner traveling margaret lee runbeck happiness quotes inspirational',
#  'safe ways heal acne altwaystoheal healthy healing',
#  'creating right now beats makingbeats thursday work istandard akaiproâ',
#  'wedding number  ðððððð¾ð¾ wedding weddingpay love forever weddingdressâ',
#  'looking forward attending cipd ireland conference amp workshop cpd onemoreday user user',
#  'finally reached  followers twitch follower hypu stream tomorrow â',
#  'words r free u use em cost you verbal abuse hu love adult teen user',
#  'country went last year see people bring bomb stadium amp come everything football',
#  'thankful cats thankful positive',
#  'time eat bae swalscha ðâð dejeuner lunch happiness love amoureuxâ',
#  'ilovethesecret lawofattraction quiz love happiness motivation success joy lifeâ',
#  'might libtard if libtard sjw liberal politics',
#  'go down pole bgp rozthediva blackgirlspole bodyandpole live love â',
#  'argentina attack bull game d really think head empty around city side',
#  'selfserving hypocrite always keep eye bouncing ball nimrod president',
#  'nohcarolina bull up dominate bull direct whatever want do whe',
#  'building polar bear climb racing angry polar bear climb racing polar bear living cold places loo',
#  'user user want reelection money ksleg',
#  'hea orlando right now truly cannot imagine could easily happened anywhere ',
#  'alreemgroup aly_alshahawy ad cute summer photographerdubai sun hair mydubaiâ',
#  'seems like place action montreal ',
#  'user that old washed up',
#  'spirited i_am positive affirmation',
#  'thankful enteainment thankful positive',
#  'user user user shows truly bad brisbane',
#  'user cant wait wimbledon',
#  'happy man success model entrepreneur speaker ff fresh confident fashionâ',
#  'gala moments  day kid bipolar frikiegirl  lucky chinatown mall binondoâ',
#  'really takes piss angry goes show valued isnt complete utter moron',
#  'user take trash america  voted hate  voted  voted  votâ',
#  'fathers day amazing dads give much families enjoy your',
#  'magnettherapy really work altwaystoheal healing healthy ',
#  'sebbo said all user',
#  'ðððâï egãï¼ï¼ï¼ smileâïððð½ ã smileegsmile torio',
#  'user brilliant service kettering branch today customer',
#  'user screening miss it sing songs potp shock treatment can',
#  'way toraya bus alamindah white music carrieunderwood',
#  'model love u take u time urð ðððð ððð',
#  'good day   new beers bridpo food amp beer fest back campsite drunk user starstruck amp moved user ',
#  'g l ð repost user propey ocean summer life family  sydneyâ',
#  'want teach love like never felt before quote quotes love pakistan allin girls boys fashion feelings',
#  'thankful now thankful positive',
#  'omg  days left countdown nolefam user cant wait come milan  ðð',
#  'user stone roses done time user club days',
#  'theres reason two people stay together give something nobody else can hopelly greats day',
#  'never know might crush you wakow buzz moment ride love crush dating hookup app',
#  'friend got engaged ðââïâðâð',
#  ' days lef b end classez yay risay risaypls',
#  'thursday ð may watch say needs saidâ',
#  'legendary i_am positive affirmation',
#  'united states america rest world think proven right firearms',
#  'hold open door woman woman nice thing do thats  even try deny',
#  'good weekend shows  thankful blessed  jeffreycwilliams ðâ',
#  'good hea help everyone always seem one gets hu buttrue',
#  'happiest baby ive ever knownð cute smiles babygirl beautiful niece blessed xo',
#  'ready tbc  oneteamlincoln are ð user user user user',
#  'cant wait carowinds ready see user user time rockthepark timetogetmyjesuson',
#  'already bought finding dory ticket',
#  'every minute lose sixty seconds happiness  ðª',
#  'sanjapan animeconvention see guys september',
#  'question day excited motoâsâ tech announcements moto_s question',
#  'make today count mondaymotivation livelifetothefullest healthy everydaycounts',
#  'happy morning degree anna classmate friends  â',
#  'user would u able suppo event brentwood homesta lost funding may close',
#  'happy little peoples ð happyhappy people kitten cat blackkittenâ',
#  'user user user thank much oppounity cherish forever ððð ððªððð¼',
#  'ð themeowood puppy',
#  'days till  ð',
#  'happy pharrell williams pharrellwilliams lyrics âº',
#  'user happy work conference right mindset leads cultureofdevelopment organizations workâ',
#  'lost another member family yesterday gutted rosie',
#  'yayyy trailer morrow fever super user user user',
#  'watch fancy tailss vine mad mad teeth bite pissed dog biting dogbite dogtreat',
#  'dreamcatcher bull up dominate bull direct whatever want do',
#  'ready tomorrow ððððððenglishteacher teacher ecuador',
#  'memory wonderful dad always missed eternally loved strong greatquotesâ',
#  'user user dallas shooting the video see disturbing viewer discretion play loop oveâ',
#  'itakoaloneits fine little',
#  'sunshine amp stickers kind saturday ðð½ letthembelittle childhoodunplugged',
#  'wonderful day today âï calm sunny chubbygirl glasses finnishgirl finn',
#  'buka bersama tma family yuhuuuuu tmaâ w risha meylucky amp  others mayfair townhouse pic â',
#  'loves knowðð nationalbestfriendsday true',
#  'user man ran governor ny state biggest africanamerican population â',
#  'stereotyping prejudice offer hope solutions create old repetitive hate conflictâ',
#  'get pussy quicker days ð',
#  'probably  time user comes back home ugh',
#  'model love u take u time urð ðððð ððð',
#  'user anyone playing voez kinda love game ððð game gaming girlgamer voez',
#  'manypols passed many times said nothing bluelivesmatter draintheswamp ferguson',
#  'sequoia weekend',
#  'bitches care eyebrows much  makin end week',
#  'bham pride paradereadybeyou ofbham user user user',
#  'fathersday guys play dad love ð',
#  'æååçæåä¹ bihday bogummylove foreverhope happy everydaygood nightðuser',
#  'wishing clients baby goats cuddle',
#  'positivevibes fresh love guys get some  concord mills mall',
#  'conjuring get ready scared tonight on readyornot truestory',
#  'âtoday day make change eliminate negativity choose live positive lifestyle insteadâ',
#  'user aaahh nabilah looks ð arigatou jkt happy daaay âºï iwearbanana',
#  'last day work tomorrow me self employed monday scared redditchbizhour',
#  'user im half boy half man im dumb too ðð',
#  'happy little boy smiles corbinrayp',
#  'never appropriate zero idea feeling right scared missyou whatwasthat',
#  'user magnificent monday mondaymorning mondaymotivation monday indraloka',
#  'dont understand designers print animals fabric bought user muzlin b sanasafinaz noexchangepolicy',
#  'maybe  happy hour get  ending ó¾ó¾µó¾',
#  'littlebear friend joy toddlerfriends puresweetness latergram toddlerfun',
#  'never lost loved one senseless violence get fucking opinion nd amendment',
#  'world heading could lose life leaving home orlando',
#  'heard say that trying lock shooter in kept patrons getting out',
#  'good mood flight user munich user interviews pharrell',
#  'first presentation user netherlands user',
#  'u made us proud hv reading ur words amp assured b assoment petite emotions wish u best',
#  'happiness vs joy happiness temporary leaves u hu joy last forever never leaves real tru',
#  'twinklatinboys  na slut snapshot hot nasty naughty sexy horny shy porn nude kinky xxx y',
#  'user people thankful thankful people happy thankfulthursday',
#  'creative i_am positive affirmation',
#  'held back tears cried happy tears amp finally leave week tomorrow user user canadianravers',
#  'bihday pressie mummy granny michaelkors luckygirl bihday liverpool',
#  'user stuck athens instead santorini user said windy land shocking service every level sinceâ',
#  'user happy folks first freakshake launch freaks yum dalston user',
#  'huge crowd trump',
#  'thankful saturdays thankful positive',
#  'good god why ð³',
#  'user enjoying delicious melons vegan organic fresh fruit organic healthy healthyliving life',
#  'first months weeks days till beginning end user sad timeðð',
#  'firework weeheeeee ðððððððððððð â',
#  'blackpool attack bull game d really think head empty around city side',
#  'fathersday amazing fathers today',
#  'want  much ask for ð',
#  'user ready waiting newblood',
#  'sad aunt passed away  funeral',
#  ' horribly ads  made us cringe',
#  'mind robsonkanu s decent player available free transfer',
#  'user come user you better this please put user s shoes unnecessary stress hâ',
#  'stalk me watch me peon poor disabled kill methis usa usa used b proud amp universe care ',
#  'stephcurrys outburst begs question christians get  nbafinals',
#  'grateful  affirmations',
#  ' weeks go im san antonio bound see user cant wait see little brother missyou mybrotherskeeper',
#  'listen gtgtgtgtgtgtgt',
#  'user the dying light village greentownÂ² antisemitism hocoschools columbiamd hocomd',
#  'hahaha last friday amp weird',
#  'hey noticed u training lover ask u check free app known my training apple',
#  'sexy fuck directioner niall nialhoranfacts niallerwins hot justindrewbieber justindb believetou',
#  'user fathersday say i love you dad right now sanya whererefreshingbegins',
#  'guess back back again lifeaftersurgery ðð¼dog dogslife labrador labradorretriever lifeofsam',
#  'hey superspoilt may want check latest updates glastofest ð_',
#  'user user user user user bihday sid god bless you hav successful career',
#  'nba finals  ambivalent  love steph thompson kyrie stinking up green class doosh lebron talk guillermo',
#  'check production teams webseries episode edited truly mep webseries',
#  'model love u take u time urð ðððð ððð',
#  'user never answered statement nazis hatred amp bigotry found wâ',
#  'juneteenth independenceday foodthought rich ancestral heritage  independence hall',
#  'river gorilla simulator need adapt environment need tear city material',
#  'watching user leadership embrace amp kiss donalds ass pathetic amp  user pay pay racism amp hate ripgop',
#  'love mature ageð ðð',
#  'aww yeah good bing bong bing bong',
#  'user good feeling happens smile instalike instamood instapic',
#  'check graffiti dublin ireland music vimeo movie video europe people flow fun rafalwojcicki',
#  'oitnbseason  days aaahhhhh',
#  'user user iampossible today extraordinaryladyspeaks starawards user user htâ',
#  'sun out happy thursday âïðâïðâï breakfast sun day sunnyday sun blueâ',
#  'packing sneakpeek working yellowjackets neshl  user bhl hockey',
#  'tony sunday tonyawards',
#  'happy fathers day  dad dads there fathersday ',
#  'user theverdict in idiot country rock bluegrass beatles love pop romance',
#  'â projects week june   blog silver gold forex',
#  'user dayshappy user dayseventyseven day happiness lovelifequotes lifeâ',
#  'little brother higher tolerance alcohol me lol',
#  'wishing guy bihday  blaze says user spitting image aâ',
#  'thankful hiking trails thankful positive',
#  'pay meeting tackle movie uncovers problem want world know',
#  'user chill relaxing piano music keep pet quiet julyth fireworks â',
#  'might libtard if libtard sjw liberal politics',
#  'user nothing says merica like user tweet',
#  'always paratyphoid',
#  'user today lost thevoice sister senselessly  sing love death people stopthehate ripchristina',
#  'guys concerned twitter brand honest followers',
#  'hate like  family really born big ass toxic bomb mother fuckers give fuck cuz got money',
#  'get up get get enjoy music today free apps free music',
#  'best lawofattraction resources healing altwaystoheal healthy  idwp ',
#  'trump ny cochair makes racist remarks michelle obama p p fyi tcot',
#  'user fan make',
#  'music therapy tool healing altwaystoheal healthy ',
#  'food make family fight mxm',
#  'delicious sangriasaludcheers smile  pub pembroke',
#  'fabulous weekend beautiful souls nofilter ð',
#  'feeling overwhelmed look see million reasons happy again love craig',
#  'back day job shane lowry',
#  'hour right now  bottles amp drinks pm user  w chippewa st buffalo',
#  'anas  nimra  farishta  mawia  khushal            number marks obtained damn high p',
#  'monday empty without bachelorette ðð¹ð thebachelorette empty nowine',
#  'suppoing family god chivalry tradition pride ones heritage controversial',
#  'user pic says otherwise young girls confined kitchen void meaning beyond cheap publicity topoli',
#  'good night  faith ever vaitacacommafiasdv',
#  'love simply love it love success work businessâ',
#  'lunchtime mom torrington lunch afterschool instadaily yummy withmom user',
#  'user sister aint even know watching argue nigga ððð waiting say wrong shit',
#  'ride out ride back done cycling sunset ride bikes fitness cardio deseâ',
#  'well gonna go see adtr bae',
#  'user tagsforlikes me foodfriendssummerswagquotes lovegodgirl weekend polaroid followme teen winjob',
#  'payintheusa polar bear climb racing angry polar bear climb racing polar bear living cold place',
#  ' healthy fam',
#  'dream palace move already stellar girls dreamy goodmorning daysâ',
#  'im waiting follow since x factor',
#  'user fault use pointscore',
#  'user week staed kinda lame getting better yay wednesdaywisdom',
#  'user forever user young man luks hot wen temper b alwys ur fan till lst breathâº hâ',
#  'worry bee',
#  'double tap follow beautiful smooth lifestyle skin instasize ff fashion â',
#  'lawofattraction healing loa healthy well idwp ',
#  'â oil turns flat  eyeing eia inventory data fuher direction blog silver gold forex',
#  'training new employees fun newblood',
#  'first bihday puppy eloise sweetbabins dog growingup cute bihdaygirl user',
#  'user   pigs burn alive saskatchewan barn fire video',
#  'user never convince americans right bear these prayfororlando guncontrol',
#  'beautiful ladies blessing know ó¾ó¾ smile lovethemâ',
#  'today baba siddique ifftar pay mumbai user amp user dono ayenge see',
#  'hands  ombre blue',
#  'user cant wait go see warcraft ugh ððð warcraft',
#  'cousins reunited familyfunuser wellness',
#  'user an audience duane henry  should insightful',
#  'train moved binge tweeting',
#  'lover stop angry visit usgtgtgt lover friend astrologer love',
#  'user blocked troll promise blacklivesmatter amp let nonsensical rants boosâ',
#  'fathers day dads ones heaven',
#  'sdlam user june  user',
#  'creepy awesome baboons climbing fire escape like humans user summev zoo',
#  'use power mind heal body altwaystoheal healthy ',
#  'dude tiger roar tiger annaswelshzoo bihdaycelebrations',
#  'user laugh happy laugh  william james xtra',
#  'happy sunday everyone think today going good day  positivevibes sunshine sunday',
#  'talk ways organizations dehumanize us never held accountable',
#  'stuck rat race find freedom masterkeyexperience',
#  'study face pizza i stole roommates idea taking pic',
#  'dinner sister ðâïðð sisteradventures sister ilovemysisterâ',
#  'else planning watching user tomorrow ð ð',
#  'usn rifle day snowed out ar closest m ever got user user user navy',
#  'euro  bbc pundits make predictions france euros sta today ',
#  'user happy ðð happiness minions',
#  'elder scrolls many years wah wah bethesda e e',
#  'user poor tiggy ð little bit cheeky jax amp ð soa throwbackthursday user user user',
#  'cannot wait eurogamer year pumped eurogamer',
#  'work russellbeckwith soon staytuned ð friend lyle tapfoags â',
#  'nazis studied american race laws inspiration â ushistory eugenics',
#  'sharing ice cream sun love outdoors picnic summer family daughter father desse icecream',
#  'nothing like river island sale shopping spree cheer retailtherapy riverisland shoppingqueen alwayscheersyouup ðð¼',
#  'cleaning ze house zoing ziy laundry ã finally free fever colds â__âim happy cleaning laundryday',
#  ' new listings up ebay woohoo sell selling buy shop shopping',
#  'thankful challenges thankful positive',
#  'chilled night ice creamamp grown up chilled',
#  'user biherism absolutely originated hateful bigotry altright hatred african american potus theresistance',
#  'user  sweets ðððððâ  instagood ììë åå idola idol à¹àààà followme selfie ããããâ',
#  'tragedies america first killing christinagrimmie orlando america safe place today',
#  'â brexit angst factor helping drive interest rates germany japan  bbh blog silver gold â',
#  'fab amp interesting day eacbpm dash quiet place dial iiba emea region meeting busy ',
#  'kayak sup snorkel swimwhatever pleasure put together alohabeachbus hawaii explore',
#  'u hold man years and watch change u hear say loyalty no',
#  'back going tacloban now see ya lateró¾µâ great â traveling tacloban city catbalogan',
#  'user feel that olympics medal',
#  'angry birds il film download ita â p hdtc  birds download film il ita',
#  'sunday ð photo user model urbex topless tits mono retweet  sexy heels ace',
#  'fo woh officer viral arrest video ârude racistâ chief crime officerâ',
#  'user user user user saturday friends',
#  'yayyyy friend got married today ððððð congratulations guys âïâï shegotmarried â',
#  'model love u take u time urð ðððð ððð',
#  'lewis remains perfect rangers announcers gonna stroke out',
#  'chris back soccer missing spring season brokenâ',
#  'train tickets booked opera week wales',
#  'beautiful day sun fun beachpark  beach park',
#  'big screen fitted right euros',
#  'love stories happy ending anime love story not ending likelikeâ',
#  'poet bull up dominate bull direct whatever want do sta',
#  'tranquil i_am positive affirmation',
#  'user name upcoming new track ðð pm kpop',
#  'best essentialoils anxiety  healthy peace  altwaystoheal ',
#  'user user user wow peoples children nothing better insult people twitter  ',
#  'thinking maybe bought user instead user gettingold becomingboring notborderlands goblizzard',
#  'fact user album hour away dripping losing mind fatkidinacandystore',
#  'ryderrideu  see cc cum together snapshot young shy kinky wet porn hot xxx horny s',
#  'ððð¼ððº snapchat gaby_china love girl snapchat flowers instasmile instaloveâ',
#  'brilliant i_am positive affirmation',
#  'user true  niggas dont go looking apaments go look shoes jewelry',
#  'safe ways heal acne altwaystoheal healthy healing',
#  'msgapparelstoday user u r special  us father day',
#  'camping next weekend lovecamping brownwood',
#  'grateful  affirmations',
#  'forever bestie ð karaoke friends friendship love nofilter instacool instagood â',
#  'user absolutely love place fantastic welcome carlos receptionist th time here room request granted usual ',
#  'headed thealter peculiar family',
#  'â us retail sales control group likely rose  mm may â danske bank blog silver gold forex',
#  'happy fathers day love life ampthe best father world âïð user fathersday love',
#  'coolestlifehack worlds smallest snake motivation',
#  'shockingly increasingly violent world live uk gun control laws feel mps family amp friends',
#  ' funny  simply truestory ',
#  'happy bihday me brithday day holidays monday menmodelsâ',
#  'saddened noone thought groom position asking opinion issue',
#  'ukrainians athletes grosseto user  watching livestream without seeing same',
#  'new season oitnb stas tonight ðð¼ oitnbseason ðð',
#  'user excited side cuain tonight looking forward seeing user broadwayâ',
#  'quay collab user says sold outððððððððððððð noooo whyyyy loveyoudesi ',
#  'finally get jordans get paid wear too lowtopsâ',
#  'impressive i_am positive affirmation',
#  'fathers day fathers making happen  salute yall ',
#  'view th floor  nyc newyorkcity myview girl wine fridaynightâ',
#  'discussing republicans thing critiquing  cant ignore consequences',
#  'got school tomorrow last integration',
#  'amen truth always lt lt love blessed',
#  'user stamford kid got  months rapebut boredomit  minutes action ',
#  'lets colorized life w rainbow danian love colour rainbow  depok',
#  'aiel aielmaharashtra rude customer care executive makes want switch loyalty another provider irritated',
#  'hi teddy corpuz rocksteddy band enjoy idol omg ððððððð',
#  'user wow great daughter are send father right fathers day cheapshot lowblow shame',
#  ' reasons happyâwhen kid midtantrum parenting tantrum toddler calm mindfulness strong',
#  'truthful i_am positive affirmation',
#  'yup siri macos wwdc   woot next work listening skills',
#  'diy done dresser nicknacks newelectricscrewdriver  brockely london',
#  'black amp feel like stomping you â retweet tampa miamiâ',
#  'user user thats problem one police officer need more bigger guns perhaps one tank soldiersâ',
#  'fathers day friends',
#  'choices fall always write candidate in â',
#  'user ëìì_êêìì_ìíëë êêìì ììµì ending',
#  'get know team behind app thats keeping tummies june issue user bazaarmagâ',
#  'actually going fishing today somewhere nice âºïð',
#  'cute look like dolls',
#  'user im',
#  'love vacation ð enjoy greece crete sabinedrift chillinn blondegirl bluedressâ',
#  'user unreal  advisors refuse take payment say wait pcn customer service ur site wasnt working',
#  'user gameready forza horizon pc time live in',
#  'user life better tahiti summer life no_school tahiti like',
#  'know males thought vagina like video games xd stupidthoughts quote lmao',
#  'pa pack taken brainwashed cheetahs downasquadmember treeouts',
#  'â japan domestic corporate goods price index yoy line expectations  may blog silver â',
#  'remember day people bbuk went become reality tv stars seems reality tv stars become big brother contestants',
#  'user allahsoil familiar become difficult stereotype  â ââ',
#  'user good morning  want live life tie goal people things',
#  'user friday lt fridayfeeling relax user bristol',
#  'days porn movie pussy pay pics',
#  'looked easy till turn rap hiphop rock funny comedy pop kanyewest',
#  'banner merry christmas new year freepik ad decoration newyear',
#  'user user yay thanks letting know pa happy man ',
#  'exam room ððð testing tired annoyed why',
#  'best homeopathic remedies anxiety  altwaystoheal healing peace ',
#  'rest peace christina',
#  'bamas fool around might raising child ppl dont think far advance see fun whatever',
#  'anti racist codeword antiwhite asia asians africa africans white countries everyonâ',
#  'user periscope first god baby graduated high school collegebound',
#  'nearly folks nervous curious finalised stuff pointers grainne bringiton',
#  'fellowship ð lifegroup',
#  'caught eating chocolate sliced bread beside ref realizing still eat dinner',
#  'user praised cleveland police rnc police consent decree  white tamirrice rip',
#  'best lawofattraction resources healing altwaystoheal healthy  idwp ',
#  'everything need surfday fathersday dads novysposnovytowelsurfgear',
#  'user  agree',
#  'user next show monday fiddlers elbow camden looking like going huge night htâ',
#  'user swimming signs everywhere parents watching  year old',
#  'mitchellrattle mitchell goodson',
#  'user getting ready saturdays jeep run nbjc  days showyourjeepday jeepmafia jeeplife jeep httâ',
#  'user attempt czech fury croatia score second',
#  'latest dairy ks thanks user user user ä½éå æ',
#  'user yep  grateful everyday  gratitude laurasworld',
#  'ebook awhile nice hard copy',
#  'nba finals game  could basketball fan ask for nbafinals',
#  'user prevent bigot',
#  'dear uot despite attempts savecharity regret announce lost her tragic rip angelic friend miss u',
#  'space place color blue fabricsourcing finished pillow cushions use usâ',
#  'perfect moment day',
#  'waited user hour come autograph finally walk awayhe comes out course disappointing',
#  'fathersday gift dad secured financial future save insure invest',
#  'girls world sexy mature housewife',
#  'time get happy saturday ð saturday weekend',
#  ' awesome dads almighty father my lord darling dad rip sweethea husband my babies daddyst son fathersday',
#  'owens football tornament football',
#  'come ee piss poor reception today Â month struggle get signal buxton put masts switching grumpy',
#  'excited na ðð',
#  'user let troopingthecolour begin  bihdayyourmajesty thequeenat htâ',
#  'work fusiona wolves last stage development chase user user',
#  'user like blacklivesmatter slogan talk ',
#  'rip little bear bear hamster rip imissyou',
#  'give hug love cats moment ð',
#  'lips like fire blood like gasoline ðð love boyfriend smile',
#  'here we go lets people icrs',
#  'life race allow present user fun',
#  'dental testimonials lichfield clients ',
#  'thank youðsoo muchð pretty user feel soo blessed amp luckyplz keep showering ur lyks meðsurprised likes unexpected',
#  'user user user nice c susanna smiling daywho needs false promises flying dragons got ben',
#  'user d back yet',
#  'got call yesterday mom diagnosed stage  ovarian cancer terrified terrified know do',
#  'user feminismiscancer feminismisterrorism feminismmuktbharat malevote ignored user',
#  'user user user side history allies issue embarrassing',
#  'fox new coming saying bluntly one things read',
#  'good morning  internationaldayofyoga yogalove yoga relax healthy positiveâ',
#  'user monkeys also declared vermin protest bajrang dal user user',
#  'user new plants user ready garden gardening know how',
#  'user coldplay last night fave ðððð coldplay conce hampden fave couple cute â',
#  'use power mind heal body  altwaystoheal healthy peace',
#  'flagday heres mine gorgeous texas sky householdname takingoverâ',
#  'aww yeah good bing bong bing bong',
#  'user yes lets thissuppoing openly prowar anti islamichomophobicrapistwho advocates samehypocrite',
#  ' cat furry persiancat    pixion  wallpapers images',
#  'good moooooorning tgif ð kiss kisses friday fridayfun',
#  'user enjoy everything already given rather always needing more blessed thankful',
#  'euro match schedule design  france vs romania  ð feedback appreciated',
#  'fathers day take dad user   love',
#  'berlin after thank much user  incredible theriveourberlin theboss',
#  'listen incubus never hus ðð nowplaying sick little world  nissan live set de user â',
#  'user anderson cooper amp lemon like gays thrown buildings sharia ndamendment',
#  'bei field dogwalking dogs',
#  'would steal awork user boohiss',
#  'competing listing today whenrealtorscompeteyouwin callme gotheextramileâ',
#  'user great park totally disorganised one poaventura whatajoke',
#  'got news you bernie winning dc even vote held last month dcvotes',
#  'â eurusd printing new monthly tops  draghi eyed blog silver gold forex',
#  'two presidential candidates everybody devolved into elections america smh usa',
#  'poor pup animals puppy vine magic subscribe youtube vine user',
#  'rare pic superstar user user bihday sivakoratala ',
#  'user user  moving outside downtown gr mi neither offer better  mbps',
#  'user wishing dadâs happy fatherâs day dads fathersday  intellicred',
#  'met girl  yrs ago online bng gay friend look like b user',
#  'face says all pwcproud',
#  ' b u  love instagood user tbt cute me beautiful followme â',
#  'enjoy weekend family home happy weekend dear friends  weekend family home',
#  'another senseless tragedy tragic pulse orlandostaystrong thoughtsandprayersâ',
#  'user loving yrkkh frm bottom hea frm day stared amp v get return uglyspat user user',
#  'captain felix rutland water little boat behind go grand adventure',
#  'binge watching series  thekilling completely avoid football',
#  'quote jeremy corbyn here we we fucking go',
#  'happyð traveltime instamood moments lovemylife russiangirl model likeâ',
#  'porn vids wwwsmallgirlsexcom',
#  'user tuesday jackie quote taketime makes soul enjoylife smile believe dream havefun',
#  'home sweet home call edinburgh since moving years ago scotland homesweethome family',
#  'play england vs russia marseille  expect high risk game plenty time drink',
#  'aww yeah good bing bong bing bong',
#  'thankful sweater weather thankful positive',
#  'haunting atmospherics studiotime',
#  'user user become fan give right criticize personal life idol',
#  'latest obsidian radio daily thanks user user user latesnews',
#  'mindblown learning much google forms workshop user cfisdrrr',
#  'user sexy prettypussy sexybbw realmvp',
#  'user back user v traumatic months damage bad thought proof plan works onwards amp upwards ð excitâ',
#  'might libtard if libtard sjw liberal politics',
#  'overwhelming evidence company trump keeps echoes sentiments amp ideals dumptrump',
#  'user yall females beefed community dick ass niggas  ðð',
#  'people like already forgot so nah new names made hashtag weekly basis',
#  'i answer ðð',
#  'cherry color symbol warm positive energy necklace price  aed stones gift amazing beautiful',
#  'cant wait  season begin lfc ynwa englishpremierleague',
#  'user happy fathers day dads except rogergoodell fathersday goodellsucksâ',
#  'â orb independent brexit poll shows leave vote ahead gbpusd slumps blog silver gold forex',
#  'user user user mm  mm  washout flooding good take set another days golf',
#  'user ya ever since zayne left never',
#  'happy fathers day â¼ïâï loveyou fathersday sunday father daddy dayâ',
#  'big shock mondayneeded find new home yeah found dream cottage tuesday',
#  'save thousands  free search x logins x brokers actor seeklearning stafresh',
#  'actually ordered kylie lip kit',
#  'hope family made arrangements make sure bastard user canât get access',
#  'ð socialmedia us firm build  nuclear reactors india',
#  'smaphone bull up dominate bull direct whatever want do',
#  'lifeisbeautiful loveit workhard trainhard matter go blessed fitlifeâ',
#  'oscar tabarez talks luis suarezâs angry reactionâ spos during luis oscar',
#  'playing njoyhit hitmusicstation us uk eur user join us nice nyc user',
#  'user  weeks go personaltrainer full time new slots available  june  pls spread tâ',
#  'mother take care ten childrens sometime ten children cant take care mother ',
#  'thankful good nightsâ sleep thankful positive',
#  'playing  bride   nocturne melancholy melancholymusic',
#  'tvkfathersday fathers day tatay daddy enjoy wathing tha voice kids',
#  'thankful friends thankful positive',
#  'thankful mason jars thankful positive',
#  'nigger lifelessons white kid grew s blogpost whitepeople respectâ',
#  'user user user congrats user',
#  'via jts user ó¾ love sinkthepink music instagay celebspot ',
#  'user ready user ccmf  mychurch frontrow upshow',
#  'utterly  people incurable stupidity africa albino killings malawi spark education campaign',
#  'â gold highs back around  blog silver gold forex',
#  'shocking events orlando  usa review gun laws innocents die first horrific unforgiveable ',
#  'knowledgeable i_am positive affirmation',
#  'le sister instatraveling instamoment igdaily instagramhub instagood instalike',
#  'feeling lonelyand ',
#  'girliguessimwithher tag saddest representation people feel forced vote her',
#  'h factor mobile app make user  want factors click download aricent whitepaper',
#  'user meanwhile google violates freespeech',
#  'happy work conference right mindset leads cultureofdevelopment organizations work mindset',
#  'user rochester attack bull chase leave lot despite fact strong source f',
#  'user competition ððµðððð¾âð¾ï',
#  'tattoosleeves gorilla simulator need adapt environment need tear city',
#  'ima go cry hours brb',
#  'tell sorrow river river taught flow without complain sepatu dahlan philosophy proverb',
#  'thankful memories thankful positive',
#  'user surely nasty piece work lmao',
#  'today perfect day  happiness lifecoach reinventimpossible',
#  'sex  sex nake women',
#  'thankful cocktails thankful positive',
#  'dont wait outside thepeel  work homophobic taxi driver guys kiss gay melbourne cabs',
#  'user guess one wanted let residents spring street know able leave hours today',
#  'great morning deborahððuser smiles kindness ð dayðð',
#  '_ windows split screen browser customcasetab noedit ',
#  'user people use tragedy like fuel hate agenda towards entire groups people thats opposite helpfulâ',
#  'taeyeon unnie fire ð btw really hope album cover yellow lol why',
#  'john micahow hell people like elected user user totalpolitician outoftouch disgraceful ð',
#  'nothing makes dad happier tasty meal fathersday',
#  'truth suicide rates young blackboys',
#  'happy sunday homesweethome amazing love istanbul girl beautiful instalike meâ',
#  'oh blocked me least love island look forward sunday ',
#  'playing  suzanne ciani    oclock morning music song',
#  'swing ðâïð swing mybabygirl baby littlegirl park love cute',
#  'help bubble attack winter bathtime cozy',
#  'moving i_am positive affirmation',
#  'thing is matter many laws regulations guns people still find way get hands them',
#  'user sunflowers  nature garden photograpy quality prints amp cards at',
#  'user didnt stay long emergency home daughter well soo rush home missed ur set',
#  'user great insights trusted professions emea growth hacking conference growthwithhubspot',
#  'carolyn cooper  ugly poor ignorant black',
#  'franklin dog sunshine dogsoftwitter',
#  'perfect day buy real furniture hiking user dinner user desseððð sleepnumber bonustolongrest dnd',
#  'happy face lovely smile user satisfying hair workit smile faceâ',
#  'ððð love you ððð  sunday weekend selfie longhair girl selfporait loveâ',
#  'nature_perfection bull hill climb reach target complete task survive str',
#  'model love u take u time urð ðððð ððð',
#  'orlando gay men angry canampt donate blood massacre ',
#  'user golinglobal  golinuntern fresh air trail running soul keeping golinuntern life balanceâ',
#  'user user monroeampnick best friends amp rosaleeampaddie kellyampbabymonrosale grimm families nadalind',
#  'user lying hillary would call security inquiry liberals like minded one eats shit eat shit',
#  'know find incredibly disrespectful taking personal call meeting frustrated ð',
#  'date night friday pub ilovehim instagay beer  billys burnet',
#  'wish user would make phones damn screens shatter cost arm leg still gotta pay fix em',
#  'hea wrenching would state mother knows son die ',
#  'user times fly less week go brilliant user leads summer conference',
#  'fruit time fruit desse instamoment photooftheday yvr sweet vancitybuzzâ',
#  'sad ones gtgtgt',
#  'sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetry  no add  follow user',
#  'user  minutes go armaanamaalontkss user user user',
#  'thank god royals  without kansas city right cleveland disgraced',
#  'get see favorite person tmrrw',
#  'latina buffalo simulation buffalo take vicinity homes do way',
#  'world live in orlando',
#  'user vacation begun triathlete triathlon coach vacation fearless rulâ httâ',
#  'user bit heabreak too reflective',
#  'user peaceful way sta morning daily chaos beginsð gratitude',
#  'hardcore girls videos birday sex xxx',
#  'takalot book order arrives time long weekend away bush bengreenfield',
#  'saysomething bull up dominate bull direct whatever want do',
#  'steph san kana s badly needed please ððð',
#  'user another hands amp feet complete berachah best  amptired',
#  'user way ctf book talk inmates paicipating user book club program slugg',
#  'ready thisâ awesome beat cool dj dance edm house goodmusic madnessâ',
#  'â jpy negative external environment remains suppoive â mufg blog silver gold forex',
#  'mkf collection jasmine moira crossbody bags wednesday',
#  'currently eat steakandshake  minutes gotten shake ordered not ',
#  'gray sad color makes feel grayneedstogo',
#  'difficult roads often lead beautiful destinations anon leadership inspiration quote inspirational',
#  'â usd long positions added eur shos increased  anz blog silver gold forex',
#  'rrockalldayer user user day noise',
#  'user no definitely mexican fakenewsale',
#  'user new album released user break up loveherbreakups hotgoss',
#  'standing racism hate americad curse congress haters deplorable hateâ',
#  'âsunshine âsunshine make ð skies âgray',
#  'something wanted say something makes happy  gaming gamer xboxone playstation user e',
#  'football actually thing mo thats watchable bringbackgladiators',
#  'happy hump day ððð humpday life lifestyle wednesday midweek snapchat walrus funnyâ',
#  'let say  love',
#  'worry happy via user archiveday weekendblogshare happiness quotes tshis',
#  'great things never came comfo zones goodtogreat inspireme love',
#  'happy puppy ðð london puppy thursdaymotivation',
#  'know going room one troubled soul a drawing blackandwhite',
#  'recommend dark amp romances  horror moviegenres ambiance',
#  'user trump used hate putin win white house trump presses attack khan family gop leaders',
#  'one bucket list items ticked tonight finally saw ice cube live tonight ð  wildlifefestival today good day ð',
#  'friends magical potion ewabeach magicalhappydrinks  ewa beach house',
#  'everytime wear soccer shis joie fries says look mexican fuck ð',
#  'weird months finally feeling positive life lately pleasedontchange ð',
#  'checked holiday croatia daystogo',
#  'user night sweet dreams',
#  'nyc seven days ð½ newyork newyorkcity travel bigapple',
#  'life make it letâs make  motivation',
#  'fashionblog rooster simulation want climb vast expanse mountains reached leakage coc',
#  'best mood ever becauseofhim inlove',
#  'happy worry ð smile love iminlove iam im in nice day',
#  'user monacorestochezedgardgrandprixf essaissunlewissuppoðð user amour love âï',
#  'bought launch using design thinkingby user amp user via user  toread letsmake',
#  'sukhbir badal announces officebearers eastcoast zone canada',
#  'mad chose dj snake zedd edc',
#  'mango wood lett gbp  get here shop cool home fun',
#  'danger white liberalism oveurning applies liberal men feminism too',
#  'user user user truly truly pathetic many ways user user user nothing learned coverinâ',
#  'monday mornings working lake scottieandrussell work love picofthedayâ',
#  'loving rain hope hangs around ð rain water tbt me weather bribieisland',
#  'user chosen wrong horse unless change mind soon end political career',
#  'user weddings impoant celebrate life possibility âanne hathaway wedding love',
#  'icymi shooting orlando nightclub kills  police say debeloping guns',
#  'user user snatched past week schoolsupplies',
#  'great aicle right money starspangledbanner slavery apaheid usa',
#  'babies born welcome new world cats babiescat cat newborn congratulations â',
#  'ððpretendingtobe when youreinpainisjustanexample ofhowstrongyouareasa personðð ððªððªððªð nightyð',
#  'user user user user user evening dear cutysððððððððððððððððððððððð',
#  'user user mentality culture mentalhealth',
#  'user wishing us weekend ðð',
#  'thankful freezers thankful positive',
#  'user ready ltagt full day lthtmlgt user user cssday',
#  'bihday cake made mom bihday mom fondant pumpkin chocolate delicious beautiful amazing',
#  'user thank you power social media user aande',
#  'user made smileâºïð bigbang babies cto',
#  'sending good vibes way happy friday tgifriday goodvibesonly becauseimhappy smilemore',
#  'letsgo agents tooeasy  days till dlc know  gamingforeveryone',
#  'holy citytissues ',
#  'user old mom bihday ð',
#  'user decide fowoh goldenretriever lcckcomfodog workingdog',
#  'user gets angry muslim assassinating  much',
#  'ðwe hereeeee ððððð user ericprydz edc music musiclife edm dance girlsâ',
#  'funny thing humankind watch news feel bad etc back open business usual good future',
#  'user keep telling aryans allowed rape women troll eod user user',
#  'user speechless comes shootings recently guess people nothing lose respectâ',
#  'user forecasted beautiful waves raalhugandu disappeared due construction bridgeamp theres hope comâ',
#  'user minute trump condemn vile bigoted comments his surrogate carlpaladino endhateâ',
#  'wishing wonderful dads fathers daylets rock today red rascalsâ',
#  'user allahsoil vps got multimillion dollar bonuses average americans lost homes ââ',
#  'love abrahamhicks lawofattraction  healthy healing joytrain ',
#  'model love u take u time urð ðððð ððð',
#  'signed first bikram yoga classâºï',
#  'think thoughts shine face like sun beams quote smile',
#  'want creative workers give enough time play success quote',
#  'hea prayers orlando victims families lgbt community',
#  ' jan interested discrimination affected criminal justice system',
#  'friends forever ðð friendsswedenreunion gratefullove  egna hem',
#  'keep opposition user endthenation',
#  'ððð love pizzaâï pizzaslicepizzasliceaoyamapizzayummydelicias goodtimeswithgoâ',
#  'two loves beer craftbeee dog malinoislovers malinois passion friend',
#  'abundant i_am positive affirmation',
#  'fathersday fatherÃÂÂs day dad  skinny and single buy things hâ',
#  'user rickityrick rickityrick ole broken wagon looking find next mateen jump board',
#  'love city great day cleveland home calm âï',
#  'guess user talking progress advancement  misogyny homophobia bigotry',
#  'teen girl killed  others injured downtown oakland shooting guns mentalillness gangs ðððððð orlando',
#  'to everyone going struggle pain right now keep head up keep smiling get it hope',
#  'good evening darling instagram babies blessed lipstick makeup fun grateful share',
#  'user jake right  many ppl lack power take stand amp drown small minded amp oft evil tendencies past',
#  'really hate hipocrit politicians sides deserve better citizens ',
#  'user user user environmental wellbeing plan sites  nothng todo wâ',
#  'bihday sway bihday sway bihdayéææå¹³ bihdayéææå¹³',
#  'saturday morning go back sleep thetrust comusic indie â faded away  johnmaun listen user',
#  'founate man life every single day father day all',
#  'user user gutted know tonight would good luck',
#  'beginning think user tom brady hater way goes man',
#  'attack orlando caused lot pain many people vengeance option  lets comfo',
#  'cuteness overloaded ð let life fills love sweetness ðð live_long married life',
#  'heading graduation user mechtechplumbing futureplumber proudmama ð',
#  'user user possible speak topic without bringing race it bigot user â',
#  'model love u take u time urð ðððð ððð',
#  'ours too much terribly news weekend orlando christinagrimmie prayers',
#  'makes  innovative_nous',
#  ' update  social analytics instalike tbt yoga summer fun',
#  'rushlimbaugh incredibly obama impression via user',
#  'user user we people failing fellow citizens',
#  'staing pack move ðð½ðð newflat',
#  'first love may his makes feel like am love cheese shotermlongdistance',
#  'user youtu bed two get friendship',
#  'want  kind poor sin despise anyone jesus faith believe wisdom',
#  'nice life done trying it lovequotes',
#  'latest positivementalattitude thanks user user user positive',
#  'want spark serious debate gun violence release photos bodies inside club orlandoshooting gunviolence',
#  'arrived blagoevgrad fo zaz conce feeling umbrelas',
#  'user number leaders coming',
#  'see user tcashowroom yesterday ðð',
#  'user mean means like ð',
#  'great way spend saturday ð relaxation positivevibes california cakesbytheocean',
#  'â eurusd could test  nearterm â westpac blog silver gold forex',
#  'money campaign asking k donations midnight fight hrcs ad buy brokedonald lyindon',
#  'today calls champagne ð¾ð¾ð¾ friday fridayfeeling friyay goodweek clients hairâ',
#  'user user user rightly so gop hates trump obama',
#  'user user user user user user user user sunday hugs',
#  ' usâââââââ me selfie myfriend loveher giannena smile thecomeback',
#  'moment decided needed more switch control lifes response default',
#  'playing  yiruma   kiss rain music song',
#  'simple true becoming capable being burnsurvivor dolbf motivation motivate',
#  'backwho missed megreatfultogod beendoinggreat selfie',
#  'not repeat put dog hot car leave heat keep home fucks sake dogs',
#  'splendid nosie me probably year wrc rallypoland user user',
#  ' hours go music video released music edinburgh scotland band user musicvideo a user',
#  'user confirmed deadaccording farrah gray pulseshooting',
#  'look journeys left right foot stage ððððð ',
#  'black professor makes assumptions entire race whilst speaking entire race next week jewsâ',
#  'back musicnow playing michael jacksonthe lost children unificationsdayand may god children amp familiessmile',
#  'drakeandjosh buffalo simulation buffalo take vicinity homes do wa',
#  'trumpusa call us homophobic misogynist really saying jealous us wâ',
#  'user think suspend indefininetly racist staff',
#  'she sat alone let sad sigh openrp bored',
#  'good morning manchester quick preview new gin launching soon one',
#  'tried new user trailnv today although feel similar vs vs smoother feel great',
#  'kiki felt ignored today user make kiki dance kikidance miabbook',
#  'user source inspiration ideal my lyf baba  fathers days',
#  'user congrats thomas new beautiful home tehaleh welcome lennar family homeowner',
#  'miss days friends played xbox ',
#  'new case scraggly hair ',
#  'user loving dincwear mums da word user straight  saturday brickingit',
#  'bihday sexy girl girls top boys naked',
#  'user one majority fans like him salty gsw fans needed someone',
#  'user changing daily basisweeks handover user network team soon av',
#  'user coming singapore',
#  'sma baby socks gbp  get here shop cool home fun',
#  'liked user video user sjw retard wants ',
#  'user woh wait user doubledown wife user user veganbeerfest vegan',
#  'user lmfao deadass ð¹',
#  'amazing interview bjmckenzie bornwin bjmuzic',
#  'boasty tuesday last night boom boom harry hype say get',
#  'bihday balayya even age mass lookcraze fanson screen romancehe legend jaibalayya',
#  'woohoo kingslanding highlandreserve house family building ourhomeâ',
#  'outlining themes wouldbe poems haha',
#  'decors buffalo simulation buffalo take vicinity homes do way',
#  'sold one two paintings going get beautiful new home week soldâ',
#  'user msg hope newyear business end  endof tedtalks tedatibm user user',
#  ' user slag children love show butreally user',
#  'safe say missing marbs sitting home watching euro listening rain depressing bringbackhappiness',
#  'brainwashed left allowing terrorist come america kill them',
#  'gd morning ðððð gdragon gd kwonjiyong jiyong vip bigbang handsome cute loveâ',
#  'friendszxc ð ððð',
#  ' days till vacation ðâïð',
#  'secret happy marriage finding people less attractive repo',
#  'python concurrency best friends code  restructure get concurrency celery developers python',
#  'womenareamazing think so induoevents     superwomen follow dowhatyoulove â',
#  'hairy pussy redtube hardcore tracks',
#  'let season  binge begin ðð oitnb myfavorite season weekendplans',
#  'rest peace ð christinagrimmie loss rip missed fan foreverinourheas',
#  'a picture woh thousand words sundayrewind hongkong travel lady lawyerâ',
#  'relax  ððð ingers followme follow followfollow beach pool relax enjoy coupleâ',
#  'user countdown begunfamilyfreeeventfestival enteainment foodstalls',
#  'awesome beginner gopro mounts super use',
#  'dear istore  please crash due heavy overload  booktime muchlove âââ',
#  'never underestimate power good book good wine good food great patio summerevening patioweather',
#  'istg best cheese ta dayum expensive',
#  'morning office routine never without bff imy',
#  'model love u take u time urð ðððð ððð',
#  'theshallows weak attempt cash jaws anniversary',
#  'user non stop election blame cspan hiding  years  pittsburgh california',
#  'weâre extremely reveal first official poster poalorigins pa  coming summer moâ',
#  ' minutes counting wwdc wwdc',
#  'user user has play ball now state politics facade lost principality',
#  'people protesting trump republican wonthey trump fuhered ampâ',
#  'great day nothing happyððð blessedthankful',
#  'happy sunday everyoneâïðâð sundaymorning sunday peace love',
#  'always help others never myself people matter clearly dont quotes latenights',
#  ' bihday weekend  even better  xx',
#  'stay strong ð selflove love iloveme quote quotes quoteoftheday happiness life wisdom wordsofwisdom',
#  'happy fathers day boys father sweet love memory user',
#  'aww yeah good bing bong bing bong',
#  'life impoant human spirit truth love give b spirituality thinkbigsundaywithmarshaððð',
#  'father babies love u happiest fathers days father via',
#  'user current mood user s web developer meet amp hire ',
#  'know getting old sta get turned on looking poweools bampq',
#  're  projects busy hands happy hands',
#  'user bride woman fine prospect happiness behind her âambrose bierce wedding love',
#  'friday xoxosamantha via',
#  'user stop robbing innocent customers hard earned aiime guys idea dey managed recharge',
#  'grab bestie amp swing hour  missed you fun eatâ',
#  'opinion racism degrading people based race justify discrimination open violence them stopracism',
#  'finally moving today ððð½',
#  'user user user way say blogger vloggerâ',
#  'user user yay fantastic edinburgh',
#  'lemme find put boiler month june',
#  'hea goes families  people killed massacre orlando',
#  'pre user gig drinks ð passthecourvoisier ðuser',
#  'rescued pup meet rexy ðâ rescuepup rexy pupsofsg suicidegirls beautiful puppylove',
#  'videos get excited futureâ tech augmented future mobile',
#  'user congrats ð ur wish come true working user ð superxcited songs ððâð',
#  'wish were',
#  'âïhellosunday hope beautiful sunday  sundayfunday sunndayð',
#  'gifdidt listen song since ages',
#  'â nzdusd rises  eyeing gdt price index fomc statement blog silver gold forex',
#  'true homefood considered cheapmeal impressions made restaurants',
#  'happy bihday one wests greatest tupac shakur ðð bihday rip tupacâ',
#  'user live life',
#  'hrs goð fl motionposter revealed mupparimanam feeling nervous ðððð stay tuned',
#  'user little taste sure',
#  'appletstag compleanno toa cake family bday selfie me smile girl summerâ',
#  'anime animea treefriends tags anime fana pixiv happy tree ',
#  'user happy nd wedding anniversary amazing husband user ð¾ðððð¼ð memories years lotstocome love',
#  'slow sta productive day getting back routine bout fatigue flareup hard spoonieproblems',
#  'love ramdan fastingi love iftars feeling love way feel ramadan praying reading quran blessed',
#  'â eurgbp subdued trading action around  blog silver gold forex',
#  'ð user ngitingtagumpay',
#  'unusual cloudy day election day picnic friends sunday everyone ó¾ó¾ welcomeludovica',
#  'cloudchaser gorilla simulator need adapt environment need tear city mat',
#  'christ alive you vlicobs xoxo love grace amen share passion church lifeâ',
#  'wants leak udta punjab probed suspects political  jobs jobsearch  chandigarh makers udt',
#  'yesterday  ozen ð restaurant eatallyoucan',
#  'already tell next weeks episode gonna give intense anxiety nervous gameofthrones',
#  'got nothing say assume that ahahahahahah',
#  'ordinary girl intruduceyourself ðð',
#  'user may lights triumph darkness may ramadan bring peace harmony joy ramadan ramadankareem',
#  'user user any else notice suppoers r pageant girls wyears internalize female oppressive system',
#  'user  reasons optimists rule world success growth balance optimism',
#  'hate online applications even get foot door tell no need you',
#  'thankful flowers thankful positive',
#  'top crappy day wme signing papers house user pop conce  blocks work amp know ',
#  'beautiful  love living beach beach loveit',
#  'user omg bitch ðððð knew gone lil kim  actually look like music video',
#  'tgif ff gamedev indiedev indiegamedev squad user user user user',
#  'user user user man even bunch coupons too',
#  'way sta day goodmorning',
#  'lking forward  watering holes watchtowers foresses user user user',
#  'user allahsoil next best seller book isis islam inworlds inwords terrorists gwot â',
#  'fantastic rub steak yum thespicesndteaexchange dc healthyâ',
#  'followme touch tits ',
#  'feels like summer ððð love like live life enjoy healthy sun tan bikini summerâ',
#  'teenageson reckons gone beyond call duty fathersday prezzie ð',
#  'user forget user  research shows sexist men psychological problems tuckercarlson',
#  'nice specific pedagogical changes ð',
#  'user typical city fan',
#  'no im attracted asian ppl bc im asian tell im attracted u bc im inse race here hoe',
#  'user awlrite mol jealous better cricket pitch life getalife',
#  'prayers go eddie family',
#  'nothappy carer finishing one week ',
#  'closeencounters fatkind fatkid dese sick tired maybemono',
#  'gymmorgon gym morning strength energy training  wingym',
#  'glad arrived safely user ',
#  'defines  historically oppressed historic oppressorsprivileged',
#  'really pretending be truthseekers empowerment selfimprovement healing ihearadio',
#  'finally found way delete old tweets might find useful well deletetweets',
#  'user view oregon poland usa unitedstates holiday dj producer houseâ',
#  'put vote yet havent share see makes you smile poll',
#  'user next chapter life stas soon looking house today fiancÃ âïðð ðð',
#  ...]

# %% [markdown]
# Mean Pooling - Take attention mask into account for correct averaging

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

# %% [markdown]
# Load AutoModel from huggingface model repository

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
#Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, max_length=24, return_tensors='pt')

# %%
#get the embeddings
with torch.no_grad():
    outputs = model(**encoded_input)

sentence_embeddings = mean_pooling(outputs, encoded_input['attention_mask'])

print('Sentence Embeddings: \n', sentence_embeddings)
